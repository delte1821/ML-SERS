# %% [markdown]
# <a href="https://colab.research.google.com/github/delte1821/ML-SERS/blob/master/ML_SERS_v1_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import os
import numpy as np
from sklearn.model_selection import train_test_split
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv1D, MaxPooling1D, Flatten, Dense, BatchNormalization, Dropout, Activation
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.metrics import mean_squared_error, r2_score, classification_report, confusion_matrix, ConfusionMatrixDisplay
from sklearn.decomposition import PCA
from sklearn.ensemble import RandomForestClassifier
import matplotlib.pyplot as plt
from matplotlib import rcParams

rcParams['font.family'] = 'sans-serif'
rcParams['font.sans-serif'] = ['DejaVu Sans']
print("Import process done")
# Out:
# Import process done

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
def __init__(file_path, display):
    self.file_path = file_path
    self.figure_path = os.path.join(file_path, "Figures")
    self.display = display
    self.fig_counter = 1  # Initialize a counter for figure saving

# %%
def load_data(file_path):
    df = pd.read_excel(file_path, header=None)
    materials = df.iloc[0, :].astype(int)  # Ensure materials are integers
    concentrations = df.iloc[1, :].astype(float)
    data = df.iloc[2:, :].values
    return data, materials, concentrations

# %%
def filter_by_material(data, materials, concentrations, material_type):
    indices = materials == material_type
    filtered_data = data[:, indices]
    filtered_concentrations = concentrations[indices]
    return filtered_data, filtered_concentrations

# %%
def preprocess_data(data):
    nsamples, nx, ny = data.shape
    data_2d = data.reshape((nsamples, nx * ny))
    scaler = StandardScaler()
    data_scaled = scaler.fit_transform(data_2d)
    data_reshaped = data_scaled.reshape(nsamples, nx, ny)
    return data_reshaped

# %%
def augment_data(data, labels, num_augmented_samples=5):
    augmented_data = []
    augmented_labels = []
    for sample, label in zip(data, labels):
        for _ in range(num_augmented_samples):
            noise = np.random.normal(0, 0.1, sample.shape)
            augmented_sample = sample + noise
            augmented_data.append(augmented_sample)
            augmented_labels.append(label)
    return np.array(augmented_data), np.array(augmented_labels)

# %%
def build_cnn_model(input_shape):
    model = Sequential([
        Conv1D(32, kernel_size=3, activation='relu', input_shape=input_shape),
        BatchNormalization(),
        MaxPooling1D(2),
        Conv1D(64, kernel_size=3, activation='relu'),
        BatchNormalization(),
        MaxPooling1D(2),
        Flatten(),
        Dense(100, activation='relu'),
        Dropout(0.5),
        Dense(1)  # Output layer for concentration prediction
    ])
    model.compile(optimizer='adam', loss='mean_squared_error')
    return model

# %%
def remove_outliers(X, y):
    z_scores_X = (X - np.mean(X)) / np.std(X)
    z_scores_y = (y - np.mean(y)) / np.std(y)
    threshold = 3
    non_outliers_X = X[abs(z_scores_X) <= threshold]
    non_outliers_y = y[abs(z_scores_y) <= threshold]
    # Ensure both X and y have the same number of samples
    min_samples = min(len(non_outliers_X), len(non_outliers_y))

    non_outliers_X = non_outliers_X[:min_samples]
    non_outliers_y = non_outliers_y[:min_samples]

    # Replace the original data with the non-outliers
    X = non_outliers_X
    y = non_outliers_y
    return X, y

# %%
def train_and_validate(data, materials, concentrations, material_types):
    results = {}
    for mat_type in material_types:
        X, y = self.filter_by_material(data, materials, concentrations, mat_type)
        #X, y = self.remove_outliers(X, y)
        X_train, X_val, y_train, y_val = train_test_split(X.T, y, test_size=0.2, random_state=42)
        X_train = X_train.reshape(X_train.shape[0], X_train.shape[1], 1)
        X_val = X_val.reshape(X_val.shape[0], X_val.shape[1], 1)

        # Data augmentation
        X_train, y_train = self.augment_data(X_train, y_train)

        X_train = self.preprocess_data(X_train)
        X_val = self.preprocess_data(X_val)

        model = self.build_cnn_model((X_train.shape[1], 1))
        print(f"Training model for material type: {mat_type}")
        history = model.fit(X_train, y_train, epochs=200, batch_size=32, validation_data=(X_val, y_val))

        y_pred = model.predict(X_val)
        mse = mean_squared_error(y_val, y_pred)
        r2 = r2_score(y_val, y_pred)
        results[mat_type] = (mse, r2, model)

        if display:
            plot_predictions(y_val, y_pred, mat_type)
            plot_training_history(history, mat_type)

    # Increment counter after completing an analysis for all material types
    fig_counter += 1
    return results

# %%
def plot_predictions(y_true, y_pred, material_type):
    material_name = "IL6" if material_type == 1 else "TNF" if material_type == 2 else "Control"
    plt.figure(figsize=(8, 6))
    plt.scatter(y_true, y_pred, c='blue')
    plt.plot([y_true.min(), y_true.max()], [y_true.min(), y_true.max()], 'k--')
    plt.xlabel('Actual Concentrations')
    plt.ylabel('Predicted Concentrations')
    plt.title(f'Actual vs Predicted Concentrations for {material_name}')
    r2 = r2_score(y_true, y_pred)
    plt.text(0.05, 0.95, f'R² = {r2:.2f}', transform=plt.gca().transAxes, fontsize=14, verticalalignment='top')
    plt.tight_layout()
    plt.savefig(os.path.join(figure_path, f'{material_name}_LR_{fig_counter}.png'))
    if display:
        plt.show()

# %%
def plot_training_history(history, material_type):
    material_name = "IL6" if material_type == 1 else "TNF" if material_type == 2 else "Control"
    plt.figure(figsize=(8, 6))
    plt.plot(history.history['loss'], label='Training Loss')
    plt.plot(history.history['val_loss'], label='Validation Loss')
    plt.title(f'Epoch vs Loss for {material_name}')
    plt.xlabel('Epoch')
    plt.ylabel('Loss')
    plt.legend()
    plt.grid(True)
    plt.tight_layout()
    plt.savefig(os.path.join(figure_path, f'{material_name}_TH_{fig_counter}.png'))
    if display:
        plt.show()

# %%
def classify_materials(data, materials):
    # Transpose data to match the materials length
    data = data.T

    scaler = StandardScaler()
    data_scaled = scaler.fit_transform(data)

    # Apply PCA
    pca = PCA(n_components=2)
    data_pca = pca.fit_transform(data_scaled)

    # Ensure the lengths match
    assert data_pca.shape[0] == len(materials), "Inconsistent number of samples between data and materials"

    # Split data
    X_train, X_val, y_train, y_val = train_test_split(data_pca, materials, test_size=0.2, random_state=42)

    # Data augmentation for classification
    X_train, y_train = self.augment_data(X_train, y_train)

    # Encode labels
    le = LabelEncoder()
    y_train_encoded = le.fit_transform(y_train)
    y_val_encoded = le.transform(y_val)

    # Train RandomForest Classifier
    clf = RandomForestClassifier(random_state=42)
    clf.fit(X_train, y_train_encoded)
    y_pred = clf.predict(X_val)

    # Decode labels
    y_pred_decoded = le.inverse_transform(y_pred)

    # Convert integer labels to strings for classification_report
    target_names = [str(label) for label in le.classes_]

    # Print classification report
    print("Material Classification Report (Validation):")
    print(classification_report(y_val_encoded, y_pred, target_names=target_names))

    # Plot confusion matrix
    plot_confusion_matrix(y_val_encoded, y_pred, target_names)

# %%
def plot_confusion_matrix(y_true, y_pred, labels):
    cm = confusion_matrix(y_true, y_pred)
    disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=labels)
    disp.plot(cmap=plt.cm.Blues)
    plt.title("Confusion Matrix")
    plt.figure(figsize=(8, 6))
    plt.tight_layout()
    plt.savefig(os.path.join(self.figure_path, f'CM_{self.fig_counter}.png'))
    if display:
        plt.show()

# %%
# Paths and instantiation
file_path = "/content/drive/My Drive/Colab Notebooks/Spectra/Low"
original_file_path = os.path.join(file_path, "Combine.xlsx")
display = True
print(original_file_path)
print(os.listdir(file_path))
# Out:
# /content/drive/My Drive/Colab Notebooks/Spectra/Low/Combine.xlsx
# ['Wavelength.xlsx', 'IL6.xlsx', 'TNF.xlsx', 'Combine.xlsx', 'Figures']

# %%
# Instantiate and use the model
sers_model = SERS(file_path, display=True)
data, materials, concentrations = sers_model.load_data(original_file_path)
material_types = [1, 2]  # Focusing on IL6 and TNF for example
results_regression = sers_model.train_and_validate(data, materials, concentrations, material_types)
# Out:
# Training model for material type: 1
# Epoch 1/200
# 16/16 [==============================] - 2s 19ms/step - loss: 1016.1791 - val_loss: 1347.5710
# Epoch 2/200
# 16/16 [==============================] - 0s 9ms/step - loss: 776.4792 - val_loss: 1208.9586
# Epoch 3/200
# 16/16 [==============================] - 0s 8ms/step - loss: 671.7935 - val_loss: 1184.2968
# Epoch 4/200
# 16/16 [==============================] - 0s 8ms/step - loss: 502.4482 - val_loss: 1073.1888
# Epoch 5/200
# 16/16 [==============================] - 0s 8ms/step - loss: 569.1124 - val_loss: 943.0920
# Epoch 6/200
# 16/16 [==============================] - 0s 9ms/step - loss: 529.6410 - val_loss: 856.4240
# Epoch 7/200
# 16/16 [==============================] - 0s 21ms/step - loss: 529.0382 - val_loss: 845.4741
# Epoch 8/200
# 16/16 [==============================] - 0s 12ms/step - loss: 523.7104 - val_loss: 836.0026
# Epoch 9/200
# 16/16 [==============================] - 0s 8ms/step - loss: 374.1988 - val_loss: 749.3383
# Epoch 10/200
# 16/16 [==============================] - 0s 7ms/step - loss: 359.3048 - val_loss: 798.3956
# Epoch 11/200
# 16/16 [==============================] - 0s 7ms/step - loss: 305.0484 - val_loss: 734.6769
# Epoch 12/200
# 16/16 [==============================] - 0s 7ms/step - loss: 254.1862 - val_loss: 677.8566
# Epoch 13/200
# 16/16 [==============================] - 0s 7ms/step - loss: 313.1064 - val_loss: 635.1155
# Epoch 14/200
# 16/16 [==============================] - 0s 7ms/step - loss: 245.6298 - val_loss: 616.5345
# Epoch 15/200
# 16/16 [==============================] - 0s 7ms/step - loss: 238.2988 - val_loss: 583.1967
# Epoch 16/200
# 16/16 [==============================] - 0s 8ms/step - loss: 213.7327 - val_loss: 594.8315
# Epoch 17/200
# 16/16 [==============================] - 0s 7ms/step - loss: 258.2772 - val_loss: 585.6437
# Epoch 18/200
# 16/16 [==============================] - 0s 7ms/step - loss: 258.8932 - val_loss: 576.4781
# Epoch 19/200
# 16/16 [==============================] - 0s 8ms/step - loss: 231.4183 - val_loss: 634.2460
# Epoch 20/200
# 16/16 [==============================] - 0s 9ms/step - loss: 217.9415 - val_loss: 540.6410
# Epoch 21/200
# 16/16 [==============================] - 0s 7ms/step - loss: 221.4108 - val_loss: 548.1775
# Epoch 22/200
# 16/16 [==============================] - 0s 7ms/step - loss: 167.8631 - val_loss: 576.1887
# Epoch 23/200
# 16/16 [==============================] - 0s 7ms/step - loss: 217.6358 - val_loss: 388.8176
# Epoch 24/200
# 16/16 [==============================] - 0s 8ms/step - loss: 228.4329 - val_loss: 556.6649
# Epoch 25/200
# 16/16 [==============================] - 0s 7ms/step - loss: 233.8230 - val_loss: 523.0308
# Epoch 26/200
# 16/16 [==============================] - 0s 7ms/step - loss: 220.3292 - val_loss: 449.0956
# Epoch 27/200
# 16/16 [==============================] - 0s 7ms/step - loss: 154.0544 - val_loss: 412.8269
# Epoch 28/200
# 16/16 [==============================] - 0s 7ms/step - loss: 159.9073 - val_loss: 481.8781
# Epoch 29/200
# 16/16 [==============================] - 0s 7ms/step - loss: 250.1054 - val_loss: 523.3909
# Epoch 30/200
# 16/16 [==============================] - 0s 7ms/step - loss: 143.3204 - val_loss: 624.5054
# Epoch 31/200
# 16/16 [==============================] - 0s 7ms/step - loss: 166.2236 - val_loss: 747.1204
# Epoch 32/200
# 16/16 [==============================] - 0s 7ms/step - loss: 141.0567 - val_loss: 570.4748
# Epoch 33/200
# 16/16 [==============================] - 0s 7ms/step - loss: 114.9745 - val_loss: 514.0798
# Epoch 34/200
# 16/16 [==============================] - 0s 7ms/step - loss: 102.4401 - val_loss: 429.1425
# Epoch 35/200
# 16/16 [==============================] - 0s 7ms/step - loss: 137.6413 - val_loss: 589.5588
# Epoch 36/200
# 16/16 [==============================] - 0s 7ms/step - loss: 114.2500 - val_loss: 483.0187
# Epoch 37/200
# 16/16 [==============================] - 0s 7ms/step - loss: 93.5913 - val_loss: 541.4443
# Epoch 38/200
# 16/16 [==============================] - 0s 7ms/step - loss: 126.9362 - val_loss: 489.9832
# Epoch 39/200
# 16/16 [==============================] - 0s 7ms/step - loss: 125.4786 - val_loss: 437.9731
# Epoch 40/200
# 16/16 [==============================] - 0s 7ms/step - loss: 128.7243 - val_loss: 357.8168
# Epoch 41/200
# 16/16 [==============================] - 0s 7ms/step - loss: 137.2570 - val_loss: 395.9720
# Epoch 42/200
# 16/16 [==============================] - 0s 8ms/step - loss: 99.7649 - val_loss: 485.5194
# Epoch 43/200
# 16/16 [==============================] - 0s 7ms/step - loss: 123.1021 - val_loss: 380.0198
# Epoch 44/200
# 16/16 [==============================] - 0s 7ms/step - loss: 87.1193 - val_loss: 391.4598
# Epoch 45/200
# 16/16 [==============================] - 0s 7ms/step - loss: 95.3142 - val_loss: 466.2707
# Epoch 46/200
# 16/16 [==============================] - 0s 7ms/step - loss: 77.5548 - val_loss: 397.9418
# Epoch 47/200
# 16/16 [==============================] - 0s 7ms/step - loss: 107.0574 - val_loss: 371.1494
# Epoch 48/200
# 16/16 [==============================] - 0s 7ms/step - loss: 112.2056 - val_loss: 470.0789
# Epoch 49/200
# 16/16 [==============================] - 0s 7ms/step - loss: 102.3703 - val_loss: 747.5722
# Epoch 50/200
# 16/16 [==============================] - 0s 8ms/step - loss: 95.7895 - val_loss: 281.3362
# Epoch 51/200
# 16/16 [==============================] - 0s 7ms/step - loss: 100.1539 - val_loss: 343.7758
# Epoch 52/200
# 16/16 [==============================] - 0s 7ms/step - loss: 92.7679 - val_loss: 529.0524
# Epoch 53/200
# 16/16 [==============================] - 0s 7ms/step - loss: 143.0558 - val_loss: 407.0081
# Epoch 54/200
# 16/16 [==============================] - 0s 7ms/step - loss: 103.2692 - val_loss: 259.9589
# Epoch 55/200
# 16/16 [==============================] - 0s 7ms/step - loss: 136.8076 - val_loss: 490.2554
# Epoch 56/200
# 16/16 [==============================] - 0s 7ms/step - loss: 91.3153 - val_loss: 199.1820
# Epoch 57/200
# 16/16 [==============================] - 0s 7ms/step - loss: 83.4010 - val_loss: 435.0893
# Epoch 58/200
# 16/16 [==============================] - 0s 7ms/step - loss: 79.4341 - val_loss: 306.5551
# Epoch 59/200
# 16/16 [==============================] - 0s 7ms/step - loss: 119.6006 - val_loss: 312.4353
# Epoch 60/200
# 16/16 [==============================] - 0s 7ms/step - loss: 112.1243 - val_loss: 185.9629
# Epoch 61/200
# 16/16 [==============================] - 0s 11ms/step - loss: 86.1461 - val_loss: 298.5859
# Epoch 62/200
# 16/16 [==============================] - 0s 14ms/step - loss: 140.4985 - val_loss: 113.6823
# Epoch 63/200
# 16/16 [==============================] - 0s 11ms/step - loss: 86.3980 - val_loss: 295.7252
# Epoch 64/200
# 16/16 [==============================] - 0s 21ms/step - loss: 92.9336 - val_loss: 259.9843
# Epoch 65/200
# 16/16 [==============================] - 0s 15ms/step - loss: 76.9017 - val_loss: 208.2966
# Epoch 66/200
# 16/16 [==============================] - 0s 14ms/step - loss: 80.9017 - val_loss: 188.8255
# Epoch 67/200
# 16/16 [==============================] - 0s 19ms/step - loss: 112.4245 - val_loss: 223.2475
# Epoch 68/200
# 16/16 [==============================] - 0s 19ms/step - loss: 86.9510 - val_loss: 742.1526
# Epoch 69/200
# 16/16 [==============================] - 0s 21ms/step - loss: 79.2459 - val_loss: 401.5203
# Epoch 70/200
# 16/16 [==============================] - 0s 17ms/step - loss: 101.2788 - val_loss: 258.2996
# Epoch 71/200
# 16/16 [==============================] - 0s 20ms/step - loss: 97.4182 - val_loss: 288.7484
# Epoch 72/200
# 16/16 [==============================] - 0s 30ms/step - loss: 89.2392 - val_loss: 392.0848
# Epoch 73/200
# 16/16 [==============================] - 0s 28ms/step - loss: 76.0784 - val_loss: 446.5749
# Epoch 74/200
# 16/16 [==============================] - 0s 18ms/step - loss: 88.0671 - val_loss: 285.7650
# Epoch 75/200
# 16/16 [==============================] - 0s 11ms/step - loss: 66.8282 - val_loss: 307.4720
# Epoch 76/200
# 16/16 [==============================] - 0s 12ms/step - loss: 75.2101 - val_loss: 368.1260
# Epoch 77/200
# 16/16 [==============================] - 0s 12ms/step - loss: 77.7644 - val_loss: 358.0372
# Epoch 78/200
# 16/16 [==============================] - 0s 11ms/step - loss: 80.8640 - val_loss: 254.0811
# Epoch 79/200
# 16/16 [==============================] - 0s 13ms/step - loss: 78.9984 - val_loss: 366.8829
# Epoch 80/200
# 16/16 [==============================] - 0s 13ms/step - loss: 108.9246 - val_loss: 276.5346
# Epoch 81/200
# 16/16 [==============================] - 0s 9ms/step - loss: 78.9370 - val_loss: 427.0854
# Epoch 82/200
# 16/16 [==============================] - 0s 8ms/step - loss: 63.6251 - val_loss: 339.7043
# Epoch 83/200
# 16/16 [==============================] - 0s 8ms/step - loss: 101.1443 - val_loss: 306.1568
# Epoch 84/200
# 16/16 [==============================] - 0s 8ms/step - loss: 93.6461 - val_loss: 203.1120
# Epoch 85/200
# 16/16 [==============================] - 0s 7ms/step - loss: 108.6473 - val_loss: 278.7197
# Epoch 86/200
# 16/16 [==============================] - 0s 8ms/step - loss: 79.8434 - val_loss: 399.8628
# Epoch 87/200
# 16/16 [==============================] - 0s 7ms/step - loss: 96.3007 - val_loss: 225.4506
# Epoch 88/200
# 16/16 [==============================] - 0s 7ms/step - loss: 82.2312 - val_loss: 240.6398
# Epoch 89/200
# 16/16 [==============================] - 0s 7ms/step - loss: 95.3144 - val_loss: 384.2778
# Epoch 90/200
# 16/16 [==============================] - 0s 7ms/step - loss: 85.7765 - val_loss: 309.6732
# Epoch 91/200
# 16/16 [==============================] - 0s 7ms/step - loss: 96.5658 - val_loss: 308.8572
# Epoch 92/200
# 16/16 [==============================] - 0s 7ms/step - loss: 69.0071 - val_loss: 204.9999
# Epoch 93/200
# 16/16 [==============================] - 0s 7ms/step - loss: 68.5432 - val_loss: 258.7712
# Epoch 94/200
# 16/16 [==============================] - 0s 7ms/step - loss: 73.8619 - val_loss: 326.1630
# Epoch 95/200
# 16/16 [==============================] - 0s 8ms/step - loss: 74.7337 - val_loss: 495.3342
# Epoch 96/200
# 16/16 [==============================] - 0s 7ms/step - loss: 77.6533 - val_loss: 195.6011
# Epoch 97/200
# 16/16 [==============================] - 0s 7ms/step - loss: 75.1834 - val_loss: 256.6958
# Epoch 98/200
# 16/16 [==============================] - 0s 7ms/step - loss: 77.1474 - val_loss: 297.6989
# Epoch 99/200
# 16/16 [==============================] - 0s 7ms/step - loss: 85.6718 - val_loss: 381.3715
# Epoch 100/200
# 16/16 [==============================] - 0s 7ms/step - loss: 83.8337 - val_loss: 278.9805
# Epoch 101/200
# 16/16 [==============================] - 0s 7ms/step - loss: 84.5109 - val_loss: 345.2793
# Epoch 102/200
# 16/16 [==============================] - 0s 8ms/step - loss: 72.1256 - val_loss: 216.3375
# Epoch 103/200
# 16/16 [==============================] - 0s 8ms/step - loss: 65.2019 - val_loss: 390.5392
# Epoch 104/200
# 16/16 [==============================] - 0s 7ms/step - loss: 65.4420 - val_loss: 392.4162
# Epoch 105/200
# 16/16 [==============================] - 0s 7ms/step - loss: 77.6428 - val_loss: 360.9188
# Epoch 106/200
# 16/16 [==============================] - 0s 7ms/step - loss: 56.2790 - val_loss: 329.4194
# Epoch 107/200
# 16/16 [==============================] - 0s 7ms/step - loss: 76.8059 - val_loss: 313.3595
# Epoch 108/200
# 16/16 [==============================] - 0s 7ms/step - loss: 71.7420 - val_loss: 271.4795
# Epoch 109/200
# 16/16 [==============================] - 0s 7ms/step - loss: 78.6554 - val_loss: 188.1665
# Epoch 110/200
# 16/16 [==============================] - 0s 7ms/step - loss: 95.5461 - val_loss: 214.7525
# Epoch 111/200
# 16/16 [==============================] - 0s 7ms/step - loss: 86.5987 - val_loss: 217.3900
# Epoch 112/200
# 16/16 [==============================] - 0s 8ms/step - loss: 81.5445 - val_loss: 278.5617
# Epoch 113/200
# 16/16 [==============================] - 0s 7ms/step - loss: 98.3291 - val_loss: 137.9682
# Epoch 114/200
# 16/16 [==============================] - 0s 7ms/step - loss: 74.9764 - val_loss: 270.8005
# Epoch 115/200
# 16/16 [==============================] - 0s 7ms/step - loss: 84.1570 - val_loss: 270.0453
# Epoch 116/200
# 16/16 [==============================] - 0s 7ms/step - loss: 75.2109 - val_loss: 273.1858
# Epoch 117/200
# 16/16 [==============================] - 0s 7ms/step - loss: 60.6743 - val_loss: 262.7236
# Epoch 118/200
# 16/16 [==============================] - 0s 7ms/step - loss: 70.3688 - val_loss: 394.4590
# Epoch 119/200
# 16/16 [==============================] - 0s 7ms/step - loss: 73.8540 - val_loss: 382.0730
# Epoch 120/200
# 16/16 [==============================] - 0s 8ms/step - loss: 68.3804 - val_loss: 393.7440
# Epoch 121/200
# 16/16 [==============================] - 0s 7ms/step - loss: 62.4267 - val_loss: 219.2428
# Epoch 122/200
# 16/16 [==============================] - 0s 7ms/step - loss: 57.9637 - val_loss: 298.6684
# Epoch 123/200
# 16/16 [==============================] - 0s 8ms/step - loss: 71.7201 - val_loss: 251.5573
# Epoch 124/200
# 16/16 [==============================] - 0s 7ms/step - loss: 69.0661 - val_loss: 300.6564
# Epoch 125/200
# 16/16 [==============================] - 0s 7ms/step - loss: 88.1352 - val_loss: 262.4203
# Epoch 126/200
# 16/16 [==============================] - 0s 7ms/step - loss: 74.5962 - val_loss: 230.8022
# Epoch 127/200
# 16/16 [==============================] - 0s 7ms/step - loss: 70.8504 - val_loss: 481.0540
# Epoch 128/200
# 16/16 [==============================] - 0s 7ms/step - loss: 80.2647 - val_loss: 163.9704
# Epoch 129/200
# 16/16 [==============================] - 0s 8ms/step - loss: 64.0494 - val_loss: 376.4348
# Epoch 130/200
# 16/16 [==============================] - 0s 7ms/step - loss: 69.4365 - val_loss: 274.8969
# Epoch 131/200
# 16/16 [==============================] - 0s 7ms/step - loss: 63.7991 - val_loss: 286.6188
# Epoch 132/200
# 16/16 [==============================] - 0s 7ms/step - loss: 87.2243 - val_loss: 270.1566
# Epoch 133/200
# 16/16 [==============================] - 0s 7ms/step - loss: 75.8209 - val_loss: 464.1010
# Epoch 134/200
# 16/16 [==============================] - 0s 7ms/step - loss: 68.6512 - val_loss: 365.5927
# Epoch 135/200
# 16/16 [==============================] - 0s 7ms/step - loss: 79.6220 - val_loss: 222.3221
# Epoch 136/200
# 16/16 [==============================] - 0s 7ms/step - loss: 69.1214 - val_loss: 282.0271
# Epoch 137/200
# 16/16 [==============================] - 0s 7ms/step - loss: 58.8890 - val_loss: 238.4346
# Epoch 138/200
# 16/16 [==============================] - 0s 7ms/step - loss: 68.3271 - val_loss: 426.2068
# Epoch 139/200
# 16/16 [==============================] - 0s 7ms/step - loss: 90.1223 - val_loss: 440.7980
# Epoch 140/200
# 16/16 [==============================] - 0s 7ms/step - loss: 84.6406 - val_loss: 346.9879
# Epoch 141/200
# 16/16 [==============================] - 0s 7ms/step - loss: 77.2655 - val_loss: 472.8653
# Epoch 142/200
# 16/16 [==============================] - 0s 7ms/step - loss: 72.4374 - val_loss: 204.3463
# Epoch 143/200
# 16/16 [==============================] - 0s 7ms/step - loss: 71.5849 - val_loss: 249.1725
# Epoch 144/200
# 16/16 [==============================] - 0s 7ms/step - loss: 72.6400 - val_loss: 364.5289
# Epoch 145/200
# 16/16 [==============================] - 0s 7ms/step - loss: 65.5154 - val_loss: 253.3737
# Epoch 146/200
# 16/16 [==============================] - 0s 7ms/step - loss: 78.8287 - val_loss: 203.3713
# Epoch 147/200
# 16/16 [==============================] - 0s 7ms/step - loss: 65.9261 - val_loss: 181.7368
# Epoch 148/200
# 16/16 [==============================] - 0s 7ms/step - loss: 69.1900 - val_loss: 230.3555
# Epoch 149/200
# 16/16 [==============================] - 0s 7ms/step - loss: 92.7303 - val_loss: 419.2070
# Epoch 150/200
# 16/16 [==============================] - 0s 7ms/step - loss: 63.0986 - val_loss: 317.5822
# Epoch 151/200
# 16/16 [==============================] - 0s 7ms/step - loss: 75.1399 - val_loss: 345.3734
# Epoch 152/200
# 16/16 [==============================] - 0s 7ms/step - loss: 57.3436 - val_loss: 353.4776
# Epoch 153/200
# 16/16 [==============================] - 0s 7ms/step - loss: 56.7068 - val_loss: 314.9907
# Epoch 154/200
# 16/16 [==============================] - 0s 7ms/step - loss: 61.1636 - val_loss: 378.4488
# Epoch 155/200
# 16/16 [==============================] - 0s 8ms/step - loss: 68.5446 - val_loss: 254.9935
# Epoch 156/200
# 16/16 [==============================] - 0s 7ms/step - loss: 71.0179 - val_loss: 330.4820
# Epoch 157/200
# 16/16 [==============================] - 0s 7ms/step - loss: 54.2174 - val_loss: 336.9534
# Epoch 158/200
# 16/16 [==============================] - 0s 7ms/step - loss: 55.0754 - val_loss: 259.2240
# Epoch 159/200
# 16/16 [==============================] - 0s 7ms/step - loss: 58.0823 - val_loss: 292.8430
# Epoch 160/200
# 16/16 [==============================] - 0s 7ms/step - loss: 53.4874 - val_loss: 435.6183
# Epoch 161/200
# 16/16 [==============================] - 0s 7ms/step - loss: 67.2460 - val_loss: 298.3474
# Epoch 162/200
# 16/16 [==============================] - 0s 7ms/step - loss: 61.8233 - val_loss: 353.0749
# Epoch 163/200
# 16/16 [==============================] - 0s 8ms/step - loss: 61.5901 - val_loss: 491.6049
# Epoch 164/200
# 16/16 [==============================] - 0s 11ms/step - loss: 82.5143 - val_loss: 234.0513
# Epoch 165/200
# 16/16 [==============================] - 0s 11ms/step - loss: 67.1368 - val_loss: 158.8109
# Epoch 166/200
# 16/16 [==============================] - 0s 10ms/step - loss: 67.8994 - val_loss: 259.0844
# Epoch 167/200
# 16/16 [==============================] - 0s 9ms/step - loss: 69.6615 - val_loss: 262.9578
# Epoch 168/200
# 16/16 [==============================] - 0s 9ms/step - loss: 69.1105 - val_loss: 364.3782
# Epoch 169/200
# 16/16 [==============================] - 0s 9ms/step - loss: 66.0369 - val_loss: 358.8030
# Epoch 170/200
# 16/16 [==============================] - 0s 10ms/step - loss: 65.5420 - val_loss: 376.8474
# Epoch 171/200
# 16/16 [==============================] - 0s 10ms/step - loss: 61.2123 - val_loss: 378.9062
# Epoch 172/200
# 16/16 [==============================] - 0s 10ms/step - loss: 58.7256 - val_loss: 410.1491
# Epoch 173/200
# 16/16 [==============================] - 0s 10ms/step - loss: 73.4501 - val_loss: 400.6571
# Epoch 174/200
# 16/16 [==============================] - 0s 9ms/step - loss: 60.7975 - val_loss: 345.7892
# Epoch 175/200
# 16/16 [==============================] - 0s 9ms/step - loss: 64.5069 - val_loss: 153.5267
# Epoch 176/200
# 16/16 [==============================] - 0s 10ms/step - loss: 61.6574 - val_loss: 309.4182
# Epoch 177/200
# 16/16 [==============================] - 0s 9ms/step - loss: 79.2188 - val_loss: 206.0272
# Epoch 178/200
# 16/16 [==============================] - 0s 9ms/step - loss: 56.3283 - val_loss: 242.9901
# Epoch 179/200
# 16/16 [==============================] - 0s 10ms/step - loss: 61.4359 - val_loss: 329.2508
# Epoch 180/200
# 16/16 [==============================] - 0s 11ms/step - loss: 62.1848 - val_loss: 298.2266
# Epoch 181/200
# 16/16 [==============================] - 0s 9ms/step - loss: 67.4884 - val_loss: 360.2572
# Epoch 182/200
# 16/16 [==============================] - 0s 11ms/step - loss: 66.4327 - val_loss: 280.6154
# Epoch 183/200
# 16/16 [==============================] - 0s 11ms/step - loss: 67.8463 - val_loss: 171.4721
# Epoch 184/200
# 16/16 [==============================] - 0s 10ms/step - loss: 57.6573 - val_loss: 239.6982
# Epoch 185/200
# 16/16 [==============================] - 0s 10ms/step - loss: 64.5606 - val_loss: 481.5001
# Epoch 186/200
# 16/16 [==============================] - 0s 10ms/step - loss: 53.1664 - val_loss: 338.9862
# Epoch 187/200
# 16/16 [==============================] - 0s 10ms/step - loss: 50.7812 - val_loss: 317.5536
# Epoch 188/200
# 16/16 [==============================] - 0s 10ms/step - loss: 56.4523 - val_loss: 345.2909
# Epoch 189/200
# 16/16 [==============================] - 0s 11ms/step - loss: 50.3541 - val_loss: 288.8985
# Epoch 190/200
# 16/16 [==============================] - 0s 11ms/step - loss: 62.6817 - val_loss: 252.0903
# Epoch 191/200
# 16/16 [==============================] - 0s 12ms/step - loss: 58.8621 - val_loss: 231.1645
# Epoch 192/200
# 16/16 [==============================] - 0s 8ms/step - loss: 69.3359 - val_loss: 184.2544
# Epoch 193/200
# 16/16 [==============================] - 0s 8ms/step - loss: 65.0019 - val_loss: 163.8415
# Epoch 194/200
# 16/16 [==============================] - 0s 7ms/step - loss: 49.1184 - val_loss: 229.5981
# Epoch 195/200
# 16/16 [==============================] - 0s 8ms/step - loss: 60.4793 - val_loss: 330.1429
# Epoch 196/200
# 16/16 [==============================] - 0s 10ms/step - loss: 62.4360 - val_loss: 380.7387
# Epoch 197/200
# 16/16 [==============================] - 0s 7ms/step - loss: 58.3205 - val_loss: 438.0483
# Epoch 198/200
# 16/16 [==============================] - 0s 8ms/step - loss: 56.6397 - val_loss: 470.3661
# Epoch 199/200
# 16/16 [==============================] - 0s 8ms/step - loss: 70.3116 - val_loss: 448.6722
# Epoch 200/200
# 16/16 [==============================] - 0s 8ms/step - loss: 70.7229 - val_loss: 377.2258
# WARNING:tensorflow:5 out of the last 5 calls to <function Model.make_predict_function.<locals>.predict_function at 0x78de2a463130> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/1 [==============================] - 0s 109ms/step
# Training model for material type: 2
# Epoch 1/200
# 10/10 [==============================] - 2s 29ms/step - loss: 2733.0007 - val_loss: 8290.2197
# Epoch 2/200
# 10/10 [==============================] - 0s 9ms/step - loss: 1992.5042 - val_loss: 8199.8359
# Epoch 3/200
# 10/10 [==============================] - 0s 9ms/step - loss: 1590.4628 - val_loss: 7812.8638
# Epoch 4/200
# 10/10 [==============================] - 0s 9ms/step - loss: 1248.8890 - val_loss: 7392.5645
# Epoch 5/200
# 10/10 [==============================] - 0s 9ms/step - loss: 1000.1555 - val_loss: 7008.6387
# Epoch 6/200
# 10/10 [==============================] - 0s 9ms/step - loss: 787.2422 - val_loss: 6864.8149
# Epoch 7/200
# 10/10 [==============================] - 0s 9ms/step - loss: 648.8888 - val_loss: 6604.6372
# Epoch 8/200
# 10/10 [==============================] - 0s 9ms/step - loss: 483.7086 - val_loss: 6473.2012
# Epoch 9/200
# 10/10 [==============================] - 0s 8ms/step - loss: 506.3805 - val_loss: 6318.5825
# Epoch 10/200
# 10/10 [==============================] - 0s 8ms/step - loss: 324.2832 - val_loss: 6162.7070
# Epoch 11/200
# 10/10 [==============================] - 0s 9ms/step - loss: 373.8387 - val_loss: 6153.8638
# Epoch 12/200
# 10/10 [==============================] - 0s 8ms/step - loss: 295.8802 - val_loss: 6011.0205
# Epoch 13/200
# 10/10 [==============================] - 0s 8ms/step - loss: 327.1305 - val_loss: 5896.9658
# Epoch 14/200
# 10/10 [==============================] - 0s 8ms/step - loss: 322.4069 - val_loss: 5607.2656
# Epoch 15/200
# 10/10 [==============================] - 0s 7ms/step - loss: 397.8019 - val_loss: 5483.6021
# Epoch 16/200
# 10/10 [==============================] - 0s 7ms/step - loss: 300.9079 - val_loss: 5406.8364
# Epoch 17/200
# 10/10 [==============================] - 0s 8ms/step - loss: 270.1177 - val_loss: 5380.3779
# Epoch 18/200
# 10/10 [==============================] - 0s 7ms/step - loss: 294.2953 - val_loss: 5372.9976
# Epoch 19/200
# 10/10 [==============================] - 0s 7ms/step - loss: 293.2143 - val_loss: 5102.6553
# Epoch 20/200
# 10/10 [==============================] - 0s 8ms/step - loss: 259.0347 - val_loss: 4967.8252
# Epoch 21/200
# 10/10 [==============================] - 0s 8ms/step - loss: 308.7794 - val_loss: 4826.8164
# Epoch 22/200
# 10/10 [==============================] - 0s 9ms/step - loss: 267.0883 - val_loss: 4933.3286
# Epoch 23/200
# 10/10 [==============================] - 0s 7ms/step - loss: 268.2738 - val_loss: 5194.3223
# Epoch 24/200
# 10/10 [==============================] - 0s 9ms/step - loss: 364.2132 - val_loss: 4843.5532
# Epoch 25/200
# 10/10 [==============================] - 0s 7ms/step - loss: 296.9637 - val_loss: 4688.2241
# Epoch 26/200
# 10/10 [==============================] - 0s 7ms/step - loss: 235.4636 - val_loss: 4481.9858
# Epoch 27/200
# 10/10 [==============================] - 0s 8ms/step - loss: 278.7901 - val_loss: 4296.2227
# Epoch 28/200
# 10/10 [==============================] - 0s 7ms/step - loss: 252.4609 - val_loss: 4447.9126
# Epoch 29/200
# 10/10 [==============================] - 0s 7ms/step - loss: 284.5161 - val_loss: 4347.8394
# Epoch 30/200
# 10/10 [==============================] - 0s 7ms/step - loss: 252.8938 - val_loss: 4129.4883
# Epoch 31/200
# 10/10 [==============================] - 0s 8ms/step - loss: 274.9416 - val_loss: 4224.2871
# Epoch 32/200
# 10/10 [==============================] - 0s 8ms/step - loss: 361.3586 - val_loss: 4121.9004
# Epoch 33/200
# 10/10 [==============================] - 0s 8ms/step - loss: 313.5977 - val_loss: 3942.5969
# Epoch 34/200
# 10/10 [==============================] - 0s 8ms/step - loss: 251.8311 - val_loss: 4043.9937
# Epoch 35/200
# 10/10 [==============================] - 0s 8ms/step - loss: 230.1016 - val_loss: 3801.6152
# Epoch 36/200
# 10/10 [==============================] - 0s 9ms/step - loss: 272.7626 - val_loss: 3987.2239
# Epoch 37/200
# 10/10 [==============================] - 0s 7ms/step - loss: 227.8598 - val_loss: 3592.0127
# Epoch 38/200
# 10/10 [==============================] - 0s 7ms/step - loss: 238.9477 - val_loss: 3454.3262
# Epoch 39/200
# 10/10 [==============================] - 0s 7ms/step - loss: 278.6401 - val_loss: 3851.4316
# Epoch 40/200
# 10/10 [==============================] - 0s 7ms/step - loss: 263.7830 - val_loss: 3269.0503
# Epoch 41/200
# 10/10 [==============================] - 0s 7ms/step - loss: 267.0130 - val_loss: 3153.1719
# Epoch 42/200
# 10/10 [==============================] - 0s 7ms/step - loss: 194.5132 - val_loss: 2935.7456
# Epoch 43/200
# 10/10 [==============================] - 0s 8ms/step - loss: 197.0111 - val_loss: 2824.2683
# Epoch 44/200
# 10/10 [==============================] - 0s 7ms/step - loss: 258.6158 - val_loss: 3176.5818
# Epoch 45/200
# 10/10 [==============================] - 0s 8ms/step - loss: 212.6635 - val_loss: 3126.5227
# Epoch 46/200
# 10/10 [==============================] - 0s 8ms/step - loss: 275.8712 - val_loss: 2580.6094
# Epoch 47/200
# 10/10 [==============================] - 0s 7ms/step - loss: 277.3071 - val_loss: 2549.4573
# Epoch 48/200
# 10/10 [==============================] - 0s 7ms/step - loss: 220.8751 - val_loss: 2432.9829
# Epoch 49/200
# 10/10 [==============================] - 0s 8ms/step - loss: 186.7762 - val_loss: 2366.2703
# Epoch 50/200
# 10/10 [==============================] - 0s 7ms/step - loss: 267.1919 - val_loss: 2280.0837
# Epoch 51/200
# 10/10 [==============================] - 0s 7ms/step - loss: 241.3573 - val_loss: 1961.0537
# Epoch 52/200
# 10/10 [==============================] - 0s 8ms/step - loss: 288.3375 - val_loss: 2189.3760
# Epoch 53/200
# 10/10 [==============================] - 0s 7ms/step - loss: 269.4081 - val_loss: 1799.3846
# Epoch 54/200
# 10/10 [==============================] - 0s 7ms/step - loss: 205.7316 - val_loss: 2154.4514
# Epoch 55/200
# 10/10 [==============================] - 0s 7ms/step - loss: 263.3678 - val_loss: 1789.0209
# Epoch 56/200
# 10/10 [==============================] - 0s 7ms/step - loss: 292.2433 - val_loss: 2097.3259
# Epoch 57/200
# 10/10 [==============================] - 0s 8ms/step - loss: 271.0126 - val_loss: 1785.8673
# Epoch 58/200
# 10/10 [==============================] - 0s 7ms/step - loss: 258.9116 - val_loss: 1823.3204
# Epoch 59/200
# 10/10 [==============================] - 0s 8ms/step - loss: 275.2286 - val_loss: 1919.1395
# Epoch 60/200
# 10/10 [==============================] - 0s 7ms/step - loss: 239.0236 - val_loss: 1722.9427
# Epoch 61/200
# 10/10 [==============================] - 0s 7ms/step - loss: 224.6138 - val_loss: 1957.7690
# Epoch 62/200
# 10/10 [==============================] - 0s 9ms/step - loss: 298.0276 - val_loss: 1735.8623
# Epoch 63/200
# 10/10 [==============================] - 0s 7ms/step - loss: 216.2165 - val_loss: 1788.1271
# Epoch 64/200
# 10/10 [==============================] - 0s 7ms/step - loss: 343.2829 - val_loss: 1870.4208
# Epoch 65/200
# 10/10 [==============================] - 0s 7ms/step - loss: 347.7500 - val_loss: 1455.0425
# Epoch 66/200
# 10/10 [==============================] - 0s 7ms/step - loss: 280.7759 - val_loss: 1370.3127
# Epoch 67/200
# 10/10 [==============================] - 0s 7ms/step - loss: 259.3190 - val_loss: 1376.1801
# Epoch 68/200
# 10/10 [==============================] - 0s 7ms/step - loss: 314.8608 - val_loss: 1586.4836
# Epoch 69/200
# 10/10 [==============================] - 0s 7ms/step - loss: 255.5761 - val_loss: 1622.0826
# Epoch 70/200
# 10/10 [==============================] - 0s 7ms/step - loss: 203.2303 - val_loss: 1796.2607
# Epoch 71/200
# 10/10 [==============================] - 0s 8ms/step - loss: 262.3699 - val_loss: 1824.0099
# Epoch 72/200
# 10/10 [==============================] - 0s 8ms/step - loss: 233.5246 - val_loss: 1655.2664
# Epoch 73/200
# 10/10 [==============================] - 0s 7ms/step - loss: 222.1496 - val_loss: 1987.7628
# Epoch 74/200
# 10/10 [==============================] - 0s 7ms/step - loss: 238.9032 - val_loss: 1761.7393
# Epoch 75/200
# 10/10 [==============================] - 0s 8ms/step - loss: 255.4024 - val_loss: 1407.6094
# Epoch 76/200
# 10/10 [==============================] - 0s 7ms/step - loss: 256.2166 - val_loss: 1461.3068
# Epoch 77/200
# 10/10 [==============================] - 0s 7ms/step - loss: 249.5460 - val_loss: 1899.7241
# Epoch 78/200
# 10/10 [==============================] - 0s 10ms/step - loss: 239.7065 - val_loss: 1438.0139
# Epoch 79/200
# 10/10 [==============================] - 0s 11ms/step - loss: 263.6183 - val_loss: 2010.5359
# Epoch 80/200
# 10/10 [==============================] - 0s 11ms/step - loss: 287.8557 - val_loss: 2161.7896
# Epoch 81/200
# 10/10 [==============================] - 0s 12ms/step - loss: 312.1367 - val_loss: 1742.3311
# Epoch 82/200
# 10/10 [==============================] - 0s 13ms/step - loss: 256.1396 - val_loss: 1681.5112
# Epoch 83/200
# 10/10 [==============================] - 0s 10ms/step - loss: 200.1061 - val_loss: 1737.8367
# Epoch 84/200
# 10/10 [==============================] - 0s 10ms/step - loss: 337.5786 - val_loss: 1680.7552
# Epoch 85/200
# 10/10 [==============================] - 0s 11ms/step - loss: 234.6291 - val_loss: 1676.9609
# Epoch 86/200
# 10/10 [==============================] - 0s 9ms/step - loss: 231.1255 - val_loss: 1592.3412
# Epoch 87/200
# 10/10 [==============================] - 0s 10ms/step - loss: 178.4064 - val_loss: 1738.8215
# Epoch 88/200
# 10/10 [==============================] - 0s 12ms/step - loss: 181.5509 - val_loss: 1450.8557
# Epoch 89/200
# 10/10 [==============================] - 0s 10ms/step - loss: 260.9409 - val_loss: 1509.7347
# Epoch 90/200
# 10/10 [==============================] - 0s 13ms/step - loss: 286.8023 - val_loss: 2023.5669
# Epoch 91/200
# 10/10 [==============================] - 0s 11ms/step - loss: 227.3954 - val_loss: 1660.6140
# Epoch 92/200
# 10/10 [==============================] - 0s 11ms/step - loss: 199.1247 - val_loss: 1318.0677
# Epoch 93/200
# 10/10 [==============================] - 0s 9ms/step - loss: 204.2702 - val_loss: 1582.1317
# Epoch 94/200
# 10/10 [==============================] - 0s 10ms/step - loss: 196.0542 - val_loss: 1667.3904
# Epoch 95/200
# 10/10 [==============================] - 0s 11ms/step - loss: 223.8269 - val_loss: 1833.2078
# Epoch 96/200
# 10/10 [==============================] - 0s 10ms/step - loss: 296.5313 - val_loss: 1687.2001
# Epoch 97/200
# 10/10 [==============================] - 0s 10ms/step - loss: 255.9825 - val_loss: 1700.0166
# Epoch 98/200
# 10/10 [==============================] - 0s 10ms/step - loss: 214.2341 - val_loss: 1327.3730
# Epoch 99/200
# 10/10 [==============================] - 0s 10ms/step - loss: 304.0381 - val_loss: 2169.4783
# Epoch 100/200
# 10/10 [==============================] - 0s 11ms/step - loss: 213.7496 - val_loss: 1646.9740
# Epoch 101/200
# 10/10 [==============================] - 0s 11ms/step - loss: 265.6095 - val_loss: 1713.2966
# Epoch 102/200
# 10/10 [==============================] - 0s 10ms/step - loss: 256.8421 - val_loss: 1393.9963
# Epoch 103/200
# 10/10 [==============================] - 0s 9ms/step - loss: 193.4272 - val_loss: 1307.0685
# Epoch 104/200
# 10/10 [==============================] - 0s 11ms/step - loss: 223.0510 - val_loss: 1362.9653
# Epoch 105/200
# 10/10 [==============================] - 0s 10ms/step - loss: 183.2636 - val_loss: 1513.4458
# Epoch 106/200
# 10/10 [==============================] - 0s 11ms/step - loss: 201.2146 - val_loss: 1573.9808
# Epoch 107/200
# 10/10 [==============================] - 0s 12ms/step - loss: 186.1672 - val_loss: 1535.6755
# Epoch 108/200
# 10/10 [==============================] - 0s 10ms/step - loss: 209.4959 - val_loss: 1461.5609
# Epoch 109/200
# 10/10 [==============================] - 0s 13ms/step - loss: 271.6519 - val_loss: 1466.5262
# Epoch 110/200
# 10/10 [==============================] - 0s 10ms/step - loss: 189.8607 - val_loss: 1563.6489
# Epoch 111/200
# 10/10 [==============================] - 0s 10ms/step - loss: 188.1355 - val_loss: 1300.5603
# Epoch 112/200
# 10/10 [==============================] - 0s 11ms/step - loss: 307.3529 - val_loss: 1405.4442
# Epoch 113/200
# 10/10 [==============================] - 0s 9ms/step - loss: 268.7488 - val_loss: 1280.0033
# Epoch 114/200
# 10/10 [==============================] - 0s 12ms/step - loss: 197.0993 - val_loss: 1191.8290
# Epoch 115/200
# 10/10 [==============================] - 0s 10ms/step - loss: 346.0552 - val_loss: 1750.2400
# Epoch 116/200
# 10/10 [==============================] - 0s 11ms/step - loss: 296.3337 - val_loss: 1465.3413
# Epoch 117/200
# 10/10 [==============================] - 0s 10ms/step - loss: 257.2752 - val_loss: 1731.7668
# Epoch 118/200
# 10/10 [==============================] - 0s 10ms/step - loss: 243.6584 - val_loss: 2026.4989
# Epoch 119/200
# 10/10 [==============================] - 0s 11ms/step - loss: 242.8843 - val_loss: 1490.3741
# Epoch 120/200
# 10/10 [==============================] - 0s 10ms/step - loss: 192.0587 - val_loss: 1795.5293
# Epoch 121/200
# 10/10 [==============================] - 0s 10ms/step - loss: 151.6736 - val_loss: 1706.2556
# Epoch 122/200
# 10/10 [==============================] - 0s 10ms/step - loss: 192.3627 - val_loss: 1765.9097
# Epoch 123/200
# 10/10 [==============================] - 0s 10ms/step - loss: 215.5541 - val_loss: 1592.3812
# Epoch 124/200
# 10/10 [==============================] - 0s 12ms/step - loss: 282.0541 - val_loss: 1378.0558
# Epoch 125/200
# 10/10 [==============================] - 0s 11ms/step - loss: 233.4875 - val_loss: 2029.0850
# Epoch 126/200
# 10/10 [==============================] - 0s 11ms/step - loss: 207.5699 - val_loss: 1343.3088
# Epoch 127/200
# 10/10 [==============================] - 0s 11ms/step - loss: 173.5296 - val_loss: 1679.4502
# Epoch 128/200
# 10/10 [==============================] - 0s 8ms/step - loss: 190.3819 - val_loss: 1298.9756
# Epoch 129/200
# 10/10 [==============================] - 0s 8ms/step - loss: 228.8301 - val_loss: 1589.7977
# Epoch 130/200
# 10/10 [==============================] - 0s 8ms/step - loss: 236.6831 - val_loss: 1627.5898
# Epoch 131/200
# 10/10 [==============================] - 0s 8ms/step - loss: 172.1309 - val_loss: 1693.3124
# Epoch 132/200
# 10/10 [==============================] - 0s 8ms/step - loss: 167.2429 - val_loss: 1464.2705
# Epoch 133/200
# 10/10 [==============================] - 0s 7ms/step - loss: 207.5766 - val_loss: 1579.1733
# Epoch 134/200
# 10/10 [==============================] - 0s 8ms/step - loss: 228.4343 - val_loss: 1448.2844
# Epoch 135/200
# 10/10 [==============================] - 0s 8ms/step - loss: 196.5216 - val_loss: 1573.9258
# Epoch 136/200
# 10/10 [==============================] - 0s 8ms/step - loss: 197.0160 - val_loss: 1297.1184
# Epoch 137/200
# 10/10 [==============================] - 0s 8ms/step - loss: 219.4462 - val_loss: 1522.1609
# Epoch 138/200
# 10/10 [==============================] - 0s 10ms/step - loss: 186.9749 - val_loss: 1460.9800
# Epoch 139/200
# 10/10 [==============================] - 0s 8ms/step - loss: 234.6462 - val_loss: 1785.9034
# Epoch 140/200
# 10/10 [==============================] - 0s 8ms/step - loss: 292.2700 - val_loss: 1486.6442
# Epoch 141/200
# 10/10 [==============================] - 0s 8ms/step - loss: 227.7400 - val_loss: 1845.4323
# Epoch 142/200
# 10/10 [==============================] - 0s 10ms/step - loss: 214.1738 - val_loss: 1445.7529
# Epoch 143/200
# 10/10 [==============================] - 0s 7ms/step - loss: 217.4851 - val_loss: 1682.7987
# Epoch 144/200
# 10/10 [==============================] - 0s 7ms/step - loss: 189.6257 - val_loss: 1721.9944
# Epoch 145/200
# 10/10 [==============================] - 0s 7ms/step - loss: 195.5339 - val_loss: 1664.3726
# Epoch 146/200
# 10/10 [==============================] - 0s 7ms/step - loss: 231.0101 - val_loss: 1427.1509
# Epoch 147/200
# 10/10 [==============================] - 0s 7ms/step - loss: 156.4973 - val_loss: 1636.6885
# Epoch 148/200
# 10/10 [==============================] - 0s 9ms/step - loss: 208.3605 - val_loss: 1306.8220
# Epoch 149/200
# 10/10 [==============================] - 0s 7ms/step - loss: 212.2376 - val_loss: 1472.1084
# Epoch 150/200
# 10/10 [==============================] - 0s 7ms/step - loss: 162.3442 - val_loss: 1525.9865
# Epoch 151/200
# 10/10 [==============================] - 0s 8ms/step - loss: 172.3090 - val_loss: 1568.6464
# Epoch 152/200
# 10/10 [==============================] - 0s 8ms/step - loss: 176.5023 - val_loss: 1657.1990
# Epoch 153/200
# 10/10 [==============================] - 0s 8ms/step - loss: 176.2143 - val_loss: 1634.4452
# Epoch 154/200
# 10/10 [==============================] - 0s 7ms/step - loss: 171.1236 - val_loss: 1577.1261
# Epoch 155/200
# 10/10 [==============================] - 0s 9ms/step - loss: 172.9998 - val_loss: 1561.5435
# Epoch 156/200
# 10/10 [==============================] - 0s 8ms/step - loss: 171.3318 - val_loss: 1531.5956
# Epoch 157/200
# 10/10 [==============================] - 0s 7ms/step - loss: 243.1687 - val_loss: 1571.4280
# Epoch 158/200
# 10/10 [==============================] - 0s 7ms/step - loss: 181.8600 - val_loss: 1699.1383
# Epoch 159/200
# 10/10 [==============================] - 0s 7ms/step - loss: 195.4529 - val_loss: 1382.0297
# Epoch 160/200
# 10/10 [==============================] - 0s 9ms/step - loss: 223.8038 - val_loss: 1633.1761
# Epoch 161/200
# 10/10 [==============================] - 0s 7ms/step - loss: 173.0401 - val_loss: 1601.8820
# Epoch 162/200
# 10/10 [==============================] - 0s 7ms/step - loss: 210.5853 - val_loss: 1837.4502
# Epoch 163/200
# 10/10 [==============================] - 0s 7ms/step - loss: 196.8586 - val_loss: 1367.0820
# Epoch 164/200
# 10/10 [==============================] - 0s 8ms/step - loss: 202.6434 - val_loss: 1530.7128
# Epoch 165/200
# 10/10 [==============================] - 0s 7ms/step - loss: 196.0196 - val_loss: 1639.7100
# Epoch 166/200
# 10/10 [==============================] - 0s 7ms/step - loss: 195.2803 - val_loss: 1584.5576
# Epoch 167/200
# 10/10 [==============================] - 0s 7ms/step - loss: 162.3129 - val_loss: 1545.7490
# Epoch 168/200
# 10/10 [==============================] - 0s 8ms/step - loss: 191.8026 - val_loss: 1573.8251
# Epoch 169/200
# 10/10 [==============================] - 0s 8ms/step - loss: 244.4898 - val_loss: 1824.8977
# Epoch 170/200
# 10/10 [==============================] - 0s 7ms/step - loss: 203.8689 - val_loss: 1643.5342
# Epoch 171/200
# 10/10 [==============================] - 0s 7ms/step - loss: 165.2613 - val_loss: 1656.3083
# Epoch 172/200
# 10/10 [==============================] - 0s 7ms/step - loss: 175.8997 - val_loss: 1678.2090
# Epoch 173/200
# 10/10 [==============================] - 0s 8ms/step - loss: 240.4469 - val_loss: 1466.6434
# Epoch 174/200
# 10/10 [==============================] - 0s 7ms/step - loss: 153.7043 - val_loss: 1792.9050
# Epoch 175/200
# 10/10 [==============================] - 0s 7ms/step - loss: 177.0111 - val_loss: 1402.1382
# Epoch 176/200
# 10/10 [==============================] - 0s 8ms/step - loss: 198.4279 - val_loss: 1520.0292
# Epoch 177/200
# 10/10 [==============================] - 0s 7ms/step - loss: 194.6856 - val_loss: 1437.2574
# Epoch 178/200
# 10/10 [==============================] - 0s 7ms/step - loss: 185.2161 - val_loss: 1597.1754
# Epoch 179/200
# 10/10 [==============================] - 0s 7ms/step - loss: 174.3886 - val_loss: 1497.6385
# Epoch 180/200
# 10/10 [==============================] - 0s 7ms/step - loss: 172.5262 - val_loss: 1693.5447
# Epoch 181/200
# 10/10 [==============================] - 0s 7ms/step - loss: 193.5228 - val_loss: 1697.0027
# Epoch 182/200
# 10/10 [==============================] - 0s 7ms/step - loss: 218.4875 - val_loss: 1502.0864
# Epoch 183/200
# 10/10 [==============================] - 0s 9ms/step - loss: 197.6694 - val_loss: 1596.1327
# Epoch 184/200
# 10/10 [==============================] - 0s 7ms/step - loss: 171.9370 - val_loss: 1320.6075
# Epoch 185/200
# 10/10 [==============================] - 0s 8ms/step - loss: 188.3689 - val_loss: 1774.7462
# Epoch 186/200
# 10/10 [==============================] - 0s 8ms/step - loss: 178.6252 - val_loss: 1560.5413
# Epoch 187/200
# 10/10 [==============================] - 0s 7ms/step - loss: 194.2962 - val_loss: 1580.4561
# Epoch 188/200
# 10/10 [==============================] - 0s 8ms/step - loss: 166.3857 - val_loss: 1622.5165
# Epoch 189/200
# 10/10 [==============================] - 0s 8ms/step - loss: 153.0468 - val_loss: 1727.4802
# Epoch 190/200
# 10/10 [==============================] - 0s 8ms/step - loss: 170.3519 - val_loss: 1756.1345
# Epoch 191/200
# 10/10 [==============================] - 0s 8ms/step - loss: 183.6941 - val_loss: 1552.3568
# Epoch 192/200
# 10/10 [==============================] - 0s 8ms/step - loss: 181.1369 - val_loss: 1812.6211
# Epoch 193/200
# 10/10 [==============================] - 0s 7ms/step - loss: 148.8634 - val_loss: 1636.0876
# Epoch 194/200
# 10/10 [==============================] - 0s 9ms/step - loss: 167.4173 - val_loss: 1782.0566
# Epoch 195/200
# 10/10 [==============================] - 0s 8ms/step - loss: 176.9907 - val_loss: 1505.7279
# Epoch 196/200
# 10/10 [==============================] - 0s 8ms/step - loss: 242.4548 - val_loss: 1637.6920
# Epoch 197/200
# 10/10 [==============================] - 0s 8ms/step - loss: 189.9372 - val_loss: 1587.4764
# Epoch 198/200
# 10/10 [==============================] - 0s 10ms/step - loss: 173.7629 - val_loss: 1749.9143
# Epoch 199/200
# 10/10 [==============================] - 0s 11ms/step - loss: 162.0621 - val_loss: 1757.1903
# Epoch 200/200
# 10/10 [==============================] - 0s 7ms/step - loss: 208.5665 - val_loss: 1470.5298
# WARNING:tensorflow:6 out of the last 6 calls to <function Model.make_predict_function.<locals>.predict_function at 0x78de2a5bba30> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/1 [==============================] - 0s 125ms/step

# %%
# Check shapes
print("Data shape after transpose:", data.T.shape)
print("Materials length:", len(materials))
# Classification
sers_model.classify_materials(data, materials)
# Out:
# Data shape after transpose: (232, 1024)
# Materials length: 232
# Material Classification Report (Validation):
#               precision    recall  f1-score   support
#
#            0       0.67      0.29      0.40         7
#            1       0.91      0.95      0.93        22
#            2       0.86      1.00      0.92        18
#
#     accuracy                           0.87        47
#    macro avg       0.81      0.75      0.75        47
# weighted avg       0.85      0.87      0.85        47
